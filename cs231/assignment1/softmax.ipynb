# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
from __future__ import print_function
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt



# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.375646
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.155398 analytic: 0.155398, relative error: 1.024786e-07
# numerical: -0.685456 analytic: -0.685456, relative error: 1.491523e-08
# numerical: 0.433473 analytic: 0.433473, relative error: 2.998143e-08
# numerical: -1.788111 analytic: -1.788111, relative error: 1.479749e-08
# numerical: -0.723319 analytic: -0.723319, relative error: 2.722786e-08
# numerical: 2.702866 analytic: 2.702866, relative error: 7.359659e-09
# numerical: 4.181301 analytic: 4.181301, relative error: 2.101429e-09
# numerical: -2.671048 analytic: -2.671048, relative error: 1.516525e-08
# numerical: 2.046379 analytic: 2.046379, relative error: 1.171075e-08
# numerical: 1.179582 analytic: 1.179582, relative error: 4.248794e-09
# numerical: 0.748030 analytic: 0.748030, relative error: 2.310672e-08
# numerical: -0.282989 analytic: -0.282989, relative error: 1.303676e-08
# numerical: 4.248454 analytic: 4.248454, relative error: 7.982615e-09
# numerical: -0.706577 analytic: -0.706577, relative error: 1.282846e-08
# numerical: -1.774856 analytic: -1.774856, relative error: 2.356547e-08
# numerical: 1.100554 analytic: 1.100553, relative error: 4.248066e-08
# numerical: 2.174644 analytic: 2.174644, relative error: 1.343546e-08
# numerical: 0.382570 analytic: 0.382570, relative error: 3.114136e-09
# numerical: 0.639560 analytic: 0.639560, relative error: 2.022196e-08
# numerical: 1.130473 analytic: 1.130473, relative error: 3.115781e-09

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.375646e+00 computed in 0.063829s
# vectorized loss: 2.375646e+00 computed in 0.003006s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-7]
regularization_strengths = [2.5e4, 5e4]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for lr in np.linspace(learning_rates[0],learning_rates[1],5):
    for reg in np.linspace(regularization_strengths[0],regularization_strengths[1],5):
        sfx = Softmax()
        tic = time.time()
        sfx.train(X_train, y_train, learning_rate=lr, reg=reg,
                      num_iters=1500, verbose=True)
        toc = time.time()
        print('That tooks %fs'%(toc - tic))
        y_train_pred = sfx.predict(X_train)
        print('training accuracy: %f' % (np.mean(y_train == y_train_pred), ))
        y_val_pred = sfx.predict(X_val)
        print('validation accuracy: %f' % (np.mean(y_val == y_val_pred), ))
        results[(lr,reg)] = (np.mean(y_train == y_train_pred),np.mean(y_val == y_val_pred))
        
pass
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 385.579841
# iteration 100 / 1500: loss 233.078990
# iteration 200 / 1500: loss 141.554782
# iteration 300 / 1500: loss 86.409253
# iteration 400 / 1500: loss 53.021871
# iteration 500 / 1500: loss 32.911783
# iteration 600 / 1500: loss 20.703955
# iteration 700 / 1500: loss 13.266129
# iteration 800 / 1500: loss 8.867368
# iteration 900 / 1500: loss 6.112775
# iteration 1000 / 1500: loss 4.542300
# iteration 1100 / 1500: loss 3.491009
# iteration 1200 / 1500: loss 2.993844
# iteration 1300 / 1500: loss 2.578000
# iteration 1400 / 1500: loss 2.275541
# That tooks 5.085367s
# training accuracy: 0.349204
# validation accuracy: 0.362000
# iteration 0 / 1500: loss 487.884452
# iteration 100 / 1500: loss 260.163895
# iteration 200 / 1500: loss 139.776134
# iteration 300 / 1500: loss 75.442520
# iteration 400 / 1500: loss 41.224839
# iteration 500 / 1500: loss 22.929408
# iteration 600 / 1500: loss 13.234092
# iteration 700 / 1500: loss 8.035861
# iteration 800 / 1500: loss 5.221308
# iteration 900 / 1500: loss 3.766125
# iteration 1000 / 1500: loss 2.955586
# iteration 1100 / 1500: loss 2.503778
# iteration 1200 / 1500: loss 2.272358
# iteration 1300 / 1500: loss 2.155467
# iteration 1400 / 1500: loss 2.129807
# That tooks 5.231021s
# training accuracy: 0.347490
# validation accuracy: 0.352000
# iteration 0 / 1500: loss 583.079033
# iteration 100 / 1500: loss 274.160964
# iteration 200 / 1500: loss 129.917090
# iteration 300 / 1500: loss 62.342322
# iteration 400 / 1500: loss 30.329265
# iteration 500 / 1500: loss 15.421140
# iteration 600 / 1500: loss 8.220359
# iteration 700 / 1500: loss 5.007218
# iteration 800 / 1500: loss 3.348018
# iteration 900 / 1500: loss 2.685745
# iteration 1000 / 1500: loss 2.361173
# iteration 1100 / 1500: loss 2.198794
# iteration 1200 / 1500: loss 2.161891
# iteration 1300 / 1500: loss 2.135293
# iteration 1400 / 1500: loss 2.109894
# That tooks 5.104350s
# training accuracy: 0.338163
# validation accuracy: 0.350000
# iteration 0 / 1500: loss 676.064145
# iteration 100 / 1500: loss 281.383916
# iteration 200 / 1500: loss 117.897044
# iteration 300 / 1500: loss 50.141010
# iteration 400 / 1500: loss 22.067613
# iteration 500 / 1500: loss 10.321356
# iteration 600 / 1500: loss 5.536715
# iteration 700 / 1500: loss 3.494380
# iteration 800 / 1500: loss 2.697565
# iteration 900 / 1500: loss 2.351693
# iteration 1000 / 1500: loss 2.206803
# iteration 1100 / 1500: loss 2.154690
# iteration 1200 / 1500: loss 2.101413
# iteration 1300 / 1500: loss 2.025196
# iteration 1400 / 1500: loss 2.054829
# That tooks 5.143258s
# training accuracy: 0.332551
# validation accuracy: 0.349000
# iteration 0 / 1500: loss 768.792741
# iteration 100 / 1500: loss 282.157964
# iteration 200 / 1500: loss 104.488383
# iteration 300 / 1500: loss 39.555280
# iteration 400 / 1500: loss 15.845605
# iteration 500 / 1500: loss 7.065213
# iteration 600 / 1500: loss 3.933125
# iteration 700 / 1500: loss 2.724014
# iteration 800 / 1500: loss 2.270114
# iteration 900 / 1500: loss 2.111579
# iteration 1000 / 1500: loss 2.111315
# iteration 1100 / 1500: loss 2.119963
# iteration 1200 / 1500: loss 2.117718
# iteration 1300 / 1500: loss 2.062282
# iteration 1400 / 1500: loss 2.027781
# That tooks 5.264915s
# training accuracy: 0.329612
# validation accuracy: 0.339000
# iteration 0 / 1500: loss 387.998917
# iteration 100 / 1500: loss 142.442910
# iteration 200 / 1500: loss 53.380828
# iteration 300 / 1500: loss 20.725309
# iteration 400 / 1500: loss 8.789812
# iteration 500 / 1500: loss 4.546121
# iteration 600 / 1500: loss 2.923901
# iteration 700 / 1500: loss 2.404527
# iteration 800 / 1500: loss 2.129381
# iteration 900 / 1500: loss 2.100896
# iteration 1000 / 1500: loss 2.012646
# iteration 1100 / 1500: loss 2.005913
# iteration 1200 / 1500: loss 1.980385
# iteration 1300 / 1500: loss 2.018163
# iteration 1400 / 1500: loss 2.020969
# That tooks 5.521231s
# training accuracy: 0.353531
# validation accuracy: 0.359000
# iteration 0 / 1500: loss 486.836711
# iteration 100 / 1500: loss 139.093025
# iteration 200 / 1500: loss 41.105124
# iteration 300 / 1500: loss 13.145623
# iteration 400 / 1500: loss 5.170593
# iteration 500 / 1500: loss 2.874237
# iteration 600 / 1500: loss 2.349251
# iteration 700 / 1500: loss 2.039823
# iteration 800 / 1500: loss 2.083036
# iteration 900 / 1500: loss 2.039920
# iteration 1000 / 1500: loss 2.054091
# iteration 1100 / 1500: loss 2.040118
# iteration 1200 / 1500: loss 2.088047
# iteration 1300 / 1500: loss 2.082194
# iteration 1400 / 1500: loss 2.049813
# That tooks 5.098367s
# training accuracy: 0.344020
# validation accuracy: 0.362000
# iteration 0 / 1500: loss 587.083528
# iteration 100 / 1500: loss 130.685516
# iteration 200 / 1500: loss 30.387049
# iteration 300 / 1500: loss 8.309813
# iteration 400 / 1500: loss 3.471349
# iteration 500 / 1500: loss 2.413407
# iteration 600 / 1500: loss 2.124910
# iteration 700 / 1500: loss 2.036065
# iteration 800 / 1500: loss 2.041961
# iteration 900 / 1500: loss 2.030541
# iteration 1000 / 1500: loss 2.096417
# iteration 1100 / 1500: loss 2.064143
# iteration 1200 / 1500: loss 2.118856
# iteration 1300 / 1500: loss 2.073232
# iteration 1400 / 1500: loss 2.052911
# That tooks 5.109332s
# training accuracy: 0.339796
# validation accuracy: 0.342000
# iteration 0 / 1500: loss 688.448567
# iteration 100 / 1500: loss 119.541768
# iteration 200 / 1500: loss 22.183528
# iteration 300 / 1500: loss 5.550258
# iteration 400 / 1500: loss 2.677031
# iteration 500 / 1500: loss 2.178163
# iteration 600 / 1500: loss 2.078644
# iteration 700 / 1500: loss 2.062186
# iteration 800 / 1500: loss 2.006303
# iteration 900 / 1500: loss 2.142624
# iteration 1000 / 1500: loss 2.017876
# iteration 1100 / 1500: loss 2.047027
# iteration 1200 / 1500: loss 2.019110
# iteration 1300 / 1500: loss 2.050765
# iteration 1400 / 1500: loss 2.139861
# That tooks 4.978684s
# training accuracy: 0.327633
# validation accuracy: 0.340000
# iteration 0 / 1500: loss 776.196087
# iteration 100 / 1500: loss 105.117052
# iteration 200 / 1500: loss 15.833906
# iteration 300 / 1500: loss 3.877286
# iteration 400 / 1500: loss 2.332049
# iteration 500 / 1500: loss 2.145435
# iteration 600 / 1500: loss 2.061317
# iteration 700 / 1500: loss 2.149230
# iteration 800 / 1500: loss 2.083925
# iteration 900 / 1500: loss 2.102246
# iteration 1000 / 1500: loss 2.123929
# iteration 1100 / 1500: loss 2.105700
# iteration 1200 / 1500: loss 2.160996
# iteration 1300 / 1500: loss 2.099833
# iteration 1400 / 1500: loss 2.084547
# That tooks 5.098361s
# training accuracy: 0.330306
# validation accuracy: 0.341000
# iteration 0 / 1500: loss 393.748770
# iteration 100 / 1500: loss 87.834229
# iteration 200 / 1500: loss 20.969143
# iteration 300 / 1500: loss 6.240197
# iteration 400 / 1500: loss 2.930762
# iteration 500 / 1500: loss 2.269134
# iteration 600 / 1500: loss 2.103660
# iteration 700 / 1500: loss 1.986412
# iteration 800 / 1500: loss 2.064310
# iteration 900 / 1500: loss 2.074057
# iteration 1000 / 1500: loss 2.001816
# iteration 1100 / 1500: loss 1.987192
# iteration 1200 / 1500: loss 1.999203
# iteration 1300 / 1500: loss 2.083196
# iteration 1400 / 1500: loss 2.026030
# That tooks 5.052488s
# training accuracy: 0.350286
# validation accuracy: 0.356000
# iteration 0 / 1500: loss 481.270100
# iteration 100 / 1500: loss 74.058470
# iteration 200 / 1500: loss 12.944428
# iteration 300 / 1500: loss 3.715018
# iteration 400 / 1500: loss 2.274458
# iteration 500 / 1500: loss 2.033647
# iteration 600 / 1500: loss 2.003335
# iteration 700 / 1500: loss 2.036420
# iteration 800 / 1500: loss 2.077436
# iteration 900 / 1500: loss 2.025310
# iteration 1000 / 1500: loss 2.058896
# iteration 1100 / 1500: loss 2.041933
# iteration 1200 / 1500: loss 2.030410
# iteration 1300 / 1500: loss 2.080779
# iteration 1400 / 1500: loss 2.065809
# That tooks 5.091347s
# training accuracy: 0.336204
# validation accuracy: 0.346000
# iteration 0 / 1500: loss 578.471933
# iteration 100 / 1500: loss 61.437137
# iteration 200 / 1500: loss 8.161646
# iteration 300 / 1500: loss 2.737160
# iteration 400 / 1500: loss 2.196803
# iteration 500 / 1500: loss 2.110361
# iteration 600 / 1500: loss 2.048361
# iteration 700 / 1500: loss 2.068490
# iteration 800 / 1500: loss 2.054307
# iteration 900 / 1500: loss 2.103745
# iteration 1000 / 1500: loss 2.061080
# iteration 1100 / 1500: loss 2.044844
# iteration 1200 / 1500: loss 2.054726
# iteration 1300 / 1500: loss 2.055806
# iteration 1400 / 1500: loss 2.045016
# That tooks 5.059467s
# training accuracy: 0.337163
# validation accuracy: 0.344000
# iteration 0 / 1500: loss 683.987479
# iteration 100 / 1500: loss 50.109785
# iteration 200 / 1500: loss 5.438408
# iteration 300 / 1500: loss 2.291280
# iteration 400 / 1500: loss 2.093354
# iteration 500 / 1500: loss 2.017436
# iteration 600 / 1500: loss 2.121418
# iteration 700 / 1500: loss 2.106171
# iteration 800 / 1500: loss 2.025595
# iteration 900 / 1500: loss 2.012290
# iteration 1000 / 1500: loss 2.017903
# iteration 1100 / 1500: loss 2.054106
# iteration 1200 / 1500: loss 2.057910
# iteration 1300 / 1500: loss 1.997854
# iteration 1400 / 1500: loss 2.037222
# That tooks 5.120317s
# training accuracy: 0.333980
# validation accuracy: 0.359000
# iteration 0 / 1500: loss 781.668212
# iteration 100 / 1500: loss 39.549825
# iteration 200 / 1500: loss 3.884713
# iteration 300 / 1500: loss 2.162727
# iteration 400 / 1500: loss 2.146831
# iteration 500 / 1500: loss 2.050356
# iteration 600 / 1500: loss 2.039751
# iteration 700 / 1500: loss 1.990272
# iteration 800 / 1500: loss 2.099222
# iteration 900 / 1500: loss 2.049031
# iteration 1000 / 1500: loss 2.073823
# iteration 1100 / 1500: loss 2.043263
# iteration 1200 / 1500: loss 2.052463
# iteration 1300 / 1500: loss 2.122670
# iteration 1400 / 1500: loss 2.049669
# That tooks 5.018580s
# training accuracy: 0.324878
# validation accuracy: 0.349000
# iteration 0 / 1500: loss 383.262660
# iteration 100 / 1500: loss 52.216187
# iteration 200 / 1500: loss 8.783156
# iteration 300 / 1500: loss 2.913672
# iteration 400 / 1500: loss 2.120339
# iteration 500 / 1500: loss 2.163416
# iteration 600 / 1500: loss 1.994899
# iteration 700 / 1500: loss 2.136496
# iteration 800 / 1500: loss 2.023236
# iteration 900 / 1500: loss 2.018621
# iteration 1000 / 1500: loss 1.990561
# iteration 1100 / 1500: loss 2.042114
# iteration 1200 / 1500: loss 1.995239
# iteration 1300 / 1500: loss 2.011015
# iteration 1400 / 1500: loss 2.017043
# That tooks 5.552156s
# training accuracy: 0.342020
# validation accuracy: 0.360000
# iteration 0 / 1500: loss 485.133893
# iteration 100 / 1500: loss 40.581023
# iteration 200 / 1500: loss 5.126692
# iteration 300 / 1500: loss 2.316392
# iteration 400 / 1500: loss 2.069294
# iteration 500 / 1500: loss 2.105174
# iteration 600 / 1500: loss 2.036117
# iteration 700 / 1500: loss 2.046286
# iteration 800 / 1500: loss 1.975459
# iteration 900 / 1500: loss 2.049105
# iteration 1000 / 1500: loss 2.071474
# iteration 1100 / 1500: loss 2.082604
# iteration 1200 / 1500: loss 2.121371
# iteration 1300 / 1500: loss 2.041098
# iteration 1400 / 1500: loss 2.044191
# That tooks 5.091385s
# training accuracy: 0.332327
# validation accuracy: 0.340000
# iteration 0 / 1500: loss 588.930135
# iteration 100 / 1500: loss 30.271726
# iteration 200 / 1500: loss 3.425821
# iteration 300 / 1500: loss 2.110623
# iteration 400 / 1500: loss 2.037632
# iteration 500 / 1500: loss 2.126591
# iteration 600 / 1500: loss 2.007174
# iteration 700 / 1500: loss 2.023546
# iteration 800 / 1500: loss 2.086669
# iteration 900 / 1500: loss 2.021148
# iteration 1000 / 1500: loss 2.106300
# iteration 1100 / 1500: loss 2.058693
# iteration 1200 / 1500: loss 2.036711
# iteration 1300 / 1500: loss 2.030234
# iteration 1400 / 1500: loss 2.186053
# That tooks 5.412525s
# training accuracy: 0.327857
# validation accuracy: 0.336000
# iteration 0 / 1500: loss 672.598126
# iteration 100 / 1500: loss 21.502869
# iteration 200 / 1500: loss 2.667969
# iteration 300 / 1500: loss 2.072618
# iteration 400 / 1500: loss 2.094392
# iteration 500 / 1500: loss 2.019480
# iteration 600 / 1500: loss 2.141407
# iteration 700 / 1500: loss 2.117833
# iteration 800 / 1500: loss 2.104135
# iteration 900 / 1500: loss 2.093251
# iteration 1000 / 1500: loss 2.060030
# iteration 1100 / 1500: loss 2.118899
# iteration 1200 / 1500: loss 2.095313
# iteration 1300 / 1500: loss 2.048784
# iteration 1400 / 1500: loss 2.116801
# That tooks 5.113326s
# training accuracy: 0.324265
# validation accuracy: 0.338000
# iteration 0 / 1500: loss 783.032048
# iteration 100 / 1500: loss 15.594088
# iteration 200 / 1500: loss 2.291275
# iteration 300 / 1500: loss 2.078710
# iteration 400 / 1500: loss 2.103232
# iteration 500 / 1500: loss 2.058426
# iteration 600 / 1500: loss 2.120196
# iteration 700 / 1500: loss 2.057626
# iteration 800 / 1500: loss 2.062653
# iteration 900 / 1500: loss 2.100118
# iteration 1000 / 1500: loss 2.086052
# iteration 1100 / 1500: loss 2.048017
# iteration 1200 / 1500: loss 2.141957
# iteration 1300 / 1500: loss 2.049079
# iteration 1400 / 1500: loss 2.056027
# That tooks 5.086396s
# training accuracy: 0.326980
# validation accuracy: 0.340000
# iteration 0 / 1500: loss 390.311364
# iteration 100 / 1500: loss 32.892894
# iteration 200 / 1500: loss 4.460106
# iteration 300 / 1500: loss 2.279296
# iteration 400 / 1500: loss 2.004482
# iteration 500 / 1500: loss 1.960901
# iteration 600 / 1500: loss 2.101033
# iteration 700 / 1500: loss 2.127615
# iteration 800 / 1500: loss 2.027010
# iteration 900 / 1500: loss 2.038967
# iteration 1000 / 1500: loss 1.992619
# iteration 1100 / 1500: loss 2.002676
# iteration 1200 / 1500: loss 2.065988
# iteration 1300 / 1500: loss 1.976449
# iteration 1400 / 1500: loss 2.097160
# That tooks 5.044517s
# training accuracy: 0.347816
# validation accuracy: 0.362000
# iteration 0 / 1500: loss 490.398766
# iteration 100 / 1500: loss 22.655389
# iteration 200 / 1500: loss 2.911089
# iteration 300 / 1500: loss 2.099019
# iteration 400 / 1500: loss 2.084438
# iteration 500 / 1500: loss 2.019866
# iteration 600 / 1500: loss 2.061916
# iteration 700 / 1500: loss 2.054483
# iteration 800 / 1500: loss 2.044318
# iteration 900 / 1500: loss 2.063130
# iteration 1000 / 1500: loss 2.024696
# iteration 1100 / 1500: loss 2.009612
# iteration 1200 / 1500: loss 1.964306
# iteration 1300 / 1500: loss 2.067182
# iteration 1400 / 1500: loss 2.055180
# That tooks 5.120306s
# training accuracy: 0.344878
# validation accuracy: 0.345000
# iteration 0 / 1500: loss 581.459782
# iteration 100 / 1500: loss 15.019872
# iteration 200 / 1500: loss 2.283630
# iteration 300 / 1500: loss 2.096998
# iteration 400 / 1500: loss 1.961233
# iteration 500 / 1500: loss 2.059030
# iteration 600 / 1500: loss 2.018409
# iteration 700 / 1500: loss 1.971457
# iteration 800 / 1500: loss 1.999944
# iteration 900 / 1500: loss 2.017212
# iteration 1000 / 1500: loss 2.108093
# iteration 1100 / 1500: loss 2.090454
# iteration 1200 / 1500: loss 2.075764
# iteration 1300 / 1500: loss 2.060942
# iteration 1400 / 1500: loss 2.066977
# That tooks 5.074431s
# training accuracy: 0.331490
# validation accuracy: 0.354000
# iteration 0 / 1500: loss 673.208905
# iteration 100 / 1500: loss 9.964210
# iteration 200 / 1500: loss 2.134607
# iteration 300 / 1500: loss 2.122674
# iteration 400 / 1500: loss 2.068866
# iteration 500 / 1500: loss 2.099925
# iteration 600 / 1500: loss 2.085975
# iteration 700 / 1500: loss 2.065543
# iteration 800 / 1500: loss 2.094525
# iteration 900 / 1500: loss 2.020600
# iteration 1000 / 1500: loss 2.104172
# iteration 1100 / 1500: loss 2.096828
# iteration 1200 / 1500: loss 2.108908
# iteration 1300 / 1500: loss 2.047573
# iteration 1400 / 1500: loss 2.098474
# That tooks 5.205072s
# training accuracy: 0.331245
# validation accuracy: 0.344000
# iteration 0 / 1500: loss 784.554545
# iteration 100 / 1500: loss 6.913418
# iteration 200 / 1500: loss 2.100633
# iteration 300 / 1500: loss 2.110527
# iteration 400 / 1500: loss 2.082344
# iteration 500 / 1500: loss 2.107483
# iteration 600 / 1500: loss 2.101160
# iteration 700 / 1500: loss 2.057835
# iteration 800 / 1500: loss 2.074857
# iteration 900 / 1500: loss 2.097479
# iteration 1000 / 1500: loss 2.082856
# iteration 1100 / 1500: loss 2.117498
# iteration 1200 / 1500: loss 2.090949
# iteration 1300 / 1500: loss 2.073719
# iteration 1400 / 1500: loss 2.101352
# That tooks 5.629956s
# training accuracy: 0.327408
# validation accuracy: 0.347000
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.349204 val accuracy: 0.362000
# lr 1.000000e-07 reg 3.125000e+04 train accuracy: 0.347490 val accuracy: 0.352000
# lr 1.000000e-07 reg 3.750000e+04 train accuracy: 0.338163 val accuracy: 0.350000
# lr 1.000000e-07 reg 4.375000e+04 train accuracy: 0.332551 val accuracy: 0.349000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.329612 val accuracy: 0.339000
# lr 2.000000e-07 reg 2.500000e+04 train accuracy: 0.353531 val accuracy: 0.359000
# lr 2.000000e-07 reg 3.125000e+04 train accuracy: 0.344020 val accuracy: 0.362000
# lr 2.000000e-07 reg 3.750000e+04 train accuracy: 0.339796 val accuracy: 0.342000
# lr 2.000000e-07 reg 4.375000e+04 train accuracy: 0.327633 val accuracy: 0.340000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.330306 val accuracy: 0.341000
# lr 3.000000e-07 reg 2.500000e+04 train accuracy: 0.350286 val accuracy: 0.356000
# lr 3.000000e-07 reg 3.125000e+04 train accuracy: 0.336204 val accuracy: 0.346000
# lr 3.000000e-07 reg 3.750000e+04 train accuracy: 0.337163 val accuracy: 0.344000
# lr 3.000000e-07 reg 4.375000e+04 train accuracy: 0.333980 val accuracy: 0.359000
# lr 3.000000e-07 reg 5.000000e+04 train accuracy: 0.324878 val accuracy: 0.349000
# lr 4.000000e-07 reg 2.500000e+04 train accuracy: 0.342020 val accuracy: 0.360000
# lr 4.000000e-07 reg 3.125000e+04 train accuracy: 0.332327 val accuracy: 0.340000
# lr 4.000000e-07 reg 3.750000e+04 train accuracy: 0.327857 val accuracy: 0.336000
# lr 4.000000e-07 reg 4.375000e+04 train accuracy: 0.324265 val accuracy: 0.338000
# lr 4.000000e-07 reg 5.000000e+04 train accuracy: 0.326980 val accuracy: 0.340000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.347816 val accuracy: 0.362000
# lr 5.000000e-07 reg 3.125000e+04 train accuracy: 0.344878 val accuracy: 0.345000
# lr 5.000000e-07 reg 3.750000e+04 train accuracy: 0.331490 val accuracy: 0.354000
# lr 5.000000e-07 reg 4.375000e+04 train accuracy: 0.331245 val accuracy: 0.344000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.327408 val accuracy: 0.347000
# best validation accuracy achieved during cross-validation: -1.000000

# %%
        sfx = Softmax()
        tic = time.time()
        sfx.train(X_train, y_train, learning_rate=1e-7, reg=2.5e4,
                      num_iters=1500, verbose=True)
        toc = time.time()
        print('That tooks %fs'%(toc - tic))
        y_train_pred = sfx.predict(X_train)
        print('training accuracy: %f' % (np.mean(y_train == y_train_pred), ))
        y_val_pred = sfx.predict(X_val)
        print('validation accuracy: %f' % (np.mean(y_val == y_val_pred), ))
        best_softmax = sfx
# Out:
# iteration 0 / 1500: loss 393.235943
# iteration 100 / 1500: loss 237.691853
# iteration 200 / 1500: loss 144.549067
# iteration 300 / 1500: loss 88.018658
# iteration 400 / 1500: loss 54.061281
# iteration 500 / 1500: loss 33.431365
# iteration 600 / 1500: loss 21.102322
# iteration 700 / 1500: loss 13.553906
# iteration 800 / 1500: loss 9.005170
# iteration 900 / 1500: loss 6.227120
# iteration 1000 / 1500: loss 4.623188
# iteration 1100 / 1500: loss 3.520753
# iteration 1200 / 1500: loss 2.937463
# iteration 1300 / 1500: loss 2.531281
# iteration 1400 / 1500: loss 2.431905
# That tooks 5.358637s
# training accuracy: 0.349918
# validation accuracy: 0.367000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.348000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
